# %% [markdown]
# <!-- Trabalho Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Fundamentos de Linguagem Python - Do Básico a Aplicações de IA</font>
# # <font color='blue'>Lista 1 de Exercícios</font>

# %% [markdown]
# #### Exercício 1
#
# Escreva um programa que peça ao usuário para digitar seu nome e, em seguida, imprima uma mensagem de boas-vindas com o nome fornecido.

# %%
# Solução

nome = input("Digite seu nome: ")
print (f"Seja Bem vindo(a), {nome}!")
# Out:
# Digite seu nome:  Bruno
# Seja Bem vindo(a), Bruno!

# %% [markdown]
# #### Exercício 2
#
# Crie duas variáveis, numero1 e numero2, e atribua a elas valores inteiros. Calcule a soma, subtração, multiplicação e divisão dessas variáveis e imprima os resultados.

# %%
# Solução
a = 10
b = 3

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b

print(f"{a} + {b} = {soma}")
print(f"{a} - {b} = {subtracao}")
print(f"{a} * {b} = {multiplicacao}")
print(f"f{a} / {b} = {divisao}")
# Out:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# f10 / 3 = 3.3333333333333335

# %% [markdown]
# #### Exercício 3
#
# Qual é a principal diferença entre uma variável de escopo local e uma de escopo global?

# %% [markdown]
# # Solução
# Variável de escopo local, é declarada dentro de uma função. Só podem ser acessada dentro daquela função
# Variável de escopo global, é declarada de qualquer função. Podem ser acessada de qualquer lugar do código

# %% [markdown]
# #### Exercício 4
#
# Crie uma variável chamada saldo com o valor 500.50 (float). Em seguida, crie uma variável saque com o valor 200.25 (float). Subtraia o saque do saldo e imprima o saldo final formatado para duas casas decimais.

# %%
# Solução
saldo = 500.50
valor = 200.25

saldo_final = saldo - valor

print(f"Saldo final: R$ {saldo_final:.2f}")
# Out:
# Saldo final: R$ 300.25

# %% [markdown]
# #### Exercício 5
#
# Declare uma variável booleana chamada **tem_carteira_de_motorista** e atribua a ela o valor True. Imprima uma mensagem que diga "Pode dirigir" se a variável for verdadeira e "Não pode dirigir" caso contrário.

# %%
# Solução

tem_carteira_de_motorista = True

if tem_carteira_de_motorista:
    print("PODE DIRIGIR!!")
else:
    print("CLARO QUE NAO PODE!")
# Out:
# PODE DIRIGIR!!

# %% [markdown]
# #### Exercício 6
#
# Crie duas variáveis:
#
# - idade_ana = 25
# - idade_beto = 30
#
# Use operadores de comparação para verificar se a idade de Ana é menor que a de Beto e imprima o resultado booleano.

# %%
# Solução

idade_ana = 25
idade_beto = 30

resultado = idade_ana < idade_beto

print(resultado)
# Out:
# True

# %% [markdown]
# #### Exercício 7
#
# Receba um número inteiro do usuário e use o operador de módulo (%) para verificar se o número é par ou ímpar. Imprima o resultado.
#
# Obs: Não estudamos ainda os condicionais, mas pesquise se necessário e tente resolver.

# %%
# Solução

numero = int(input("Digitar um número: "))

resto = numero % 2

print(f"o número {numero} dividido por 2 tem resto {resto}")
print(f"Portanto, {numero} é {'par' if resto == 0 else 'ímpar'}")
# Out:
# Digitar um número:  1
# o número 1 dividido por 2 tem resto 1
# Portanto, 1 é ímpar

# %% [markdown]
# #### Exercício 8
#
# Crie duas variáveis booleanas:
#
# - chovendo = True
# - guarda_chuva = False
#
# Use operadores lógicos para verificar se uma pessoa vai se molhar (se está chovendo E ela não tem guarda-chuva).

# %%
# Solução
chovendo = True
guarda_chuva = False

print(f"A pessoa vai se molhar na chuva sem a gaurda-chuva? {chovendo and not guarda_chuva}")
# Out:
# A pessoa vai se molhar na chuva sem a gaurda-chuva? True

# %% [markdown]
# #### Exercício 9
#
# Calcule a potência de 2 elevado a 10 e imprima o resultado.

# %%
# Solução

a = 2
b = 10

potencia = a ** b

print(f"{a} ** {b} = {potencia}")
# Out:
# 2 ** 10 = 1024

# %% [markdown]
# #### Exercício 10
#
# Converta a string "2026" para um tipo inteiro e armazene-a em uma variável chamada ano. Em seguida, some 1 a essa variável e imprima o novo ano.

# %%
# Solução

numero_em_texto = 2026
numero_inteiro = int(numero_em_texto)
print(f"String '{numero_em_texto}' para inteiro: {numero_inteiro}, Tipo: {type(numero_inteiro)}")
# Out:
# String '2026' para inteiro: 2026, Tipo: <class 'int'>

# %% [markdown]
# #### Exercício 11
#
# Crie a string:
#
# frase = "   Python é uma linguagem poderosa e estou aprendendo com a DSA   ".
#
# Remova os espaços em branco do início e do fim da string e imprima a nova string.

# %%
# Solução

frase = "   Python é uma linguagem poderosa e estou aprendendo com a DSA   "

frase = frase.strip()
print(f"Frase sem espaços: '{frase}'")
# Out:
# Frase sem espaços: 'Python é uma linguagem poderosa e estou aprendendo com a DSA'

# %% [markdown]
# #### Exercício 12
#
# Na string do exercício anterior (já sem os espaços), converta toda a frase para letras maiúsculas.

# %%
# Solução
frase = "Python é uma linguagem poderosa e estou aprendendo com a DSA"
print(f"Maiúsculas: {frase.upper()}")
# Out:
# Maiúsculas: PYTHON É UMA LINGUAGEM PODEROSA E ESTOU APRENDENDO COM A DSA

# %% [markdown]
# #### Exercício 13
#
# Ainda usando a mesma string, substitua a palavra "poderosa" por "incrível".

# %%
# Solução

frase = "Python é uma linguagem poderosa e estou aprendendo com a DSA"
print(f"Substituindo 'poderosa' por 'incrível': {frase.replace('poderosa', 'incrível')}")
# Out:
# Substituindo 'poderosa' por 'incrível': Python é uma linguagem incrível e estou aprendendo com a DSA

# %% [markdown]
# #### Exercício 14
#
# Verifique e imprima o número total de caracteres na string frase (após as modificações dos exercícios anteriores).

# %%
# Solução
frase = "Python é uma linguagem poderosa e estou aprendendo com a DSA"
print(f"O total de caracteres na string desta frase é: {len(frase)}")
# Out:
# O total de caracteres na string desta frase é: 60

# %% [markdown]
# #### Exercício 15
#
# Use fatiamento (slicing) para extrair e imprimir apenas a palavra "Python" da string frase.

# %%
# Solução
frase = "Python é uma linguagem poderosa e estou aprendendo com a DSA"
print(frase)
print(f"A palavra que foi pedido é esse ai: {frase[0:6]}")
# Out:
# Python é uma linguagem poderosa e estou aprendendo com a DSA
# A palavra que foi pedido é esse ai: Python

# %% [markdown]
# #### Exercício 16
#
# Crie uma lista chamada compras com os seguintes itens: "arroz", "feijão", "macarrão", "carne". Imprima a lista.

# %%
# Solução
compras = ["arroz", "feijão", "macarrão", "carne"]
print(f"Lista de compras: {compras}")
# Out:
# Lista de compras: ['arroz', 'feijão', 'macarrão', 'carne']

# %% [markdown]
# #### Exercício 17
#
# Adicione o item "leite" ao final da lista compras e imprima a lista atualizada.

# %%
# Solução
compras = ["arroz", "feijão", "macarrão", "carne"]
compras.append("leite")
print(f"me pediram pra adicionar um leite na lista, então: {compras}")
# Out:
# me pediram pra adicionar um leite na lista, então: ['arroz', 'feijão', 'macarrão', 'carne', 'leite']

# %% [markdown]
# #### Exercício 18
#
# Acesse e imprima o segundo item da lista compras.

# %%
# Solução
compras = ["arroz", "feijão", "macarrão", "carne"]
print(f"o segundo item da lista de compras é: {compras[2]}")
# Out:
# o segundo item da lista de compras é: macarrão

# %% [markdown]
# #### Exercício 19
#
# Remova o item "macarrão" da lista compras e imprima a lista final.

# %%
# Solução
compras = ["arroz", "feijão", "macarrão", "carne"]
compras.remove("macarrão")
print(f"me pediram para tirar 'macarrão' na lista, então segue a lista oficial: {compras}")
# Out:
# me pediram para tirar 'macarrão' na lista, então segue a lista oficial: ['arroz', 'feijão', 'carne']

# %% [markdown]
# #### Exercício 20
#
# Crie uma lista de números de 1 a 5. Use uma função para calcular e imprimir o tamanho (número de elementos) dessa lista.

# %%
# Solução
numeros = [1, 2, 3, 4, 5]
tamanho = len(numeros)
print(f"A lista {numeros} tem {tamanho} elementos.")
# Out:
# A lista [1, 2, 3, 4, 5] tem 5 elementos.

# %% [markdown]
# #### Exercício 21
#
# Crie uma tupla chamada meses com os três primeiros meses do ano: "Janeiro", "Fevereiro", "Março".

# %%
# Solução

meses = ("Janeiro", "Fevereiro", "Março")
print(f"Tupla de meses: {meses}")
# Out:
# Tupla de meses: ('Janeiro', 'Fevereiro', 'Março')

# %% [markdown]
# #### Exercício 22
#
# Tente adicionar o mês "Abril" à tupla meses. O que acontece? Explique o resultado.

# %%
# Solução
#se eu tentar adicionar ou modificar uma tupla, vai aparecer o erro para gente! pq são imutáveis no python. 
#uma tupla é "congelada" - você só pode consultar e ler seus valores, nunca mudar nada.
#Uma tupla é como um documento plastificado - você pode ler o que está escrito, mas não pode escrever por cima, raspar, adicionar ou remover nada.
#mas tem um jeito de adicionar que é abaixo

meses = ("Janeiro", "Fevereiro", "Março")
meses = meses + ("Abril",)  # Cria nova tupla
print(meses)  # ('Janeiro', 'Fevereiro', 'Março', 'Abril')
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %% [markdown]
# #### Exercício 23
#
# Acesse e imprima o primeiro mês da tupla meses.

# %%
# Solução

meses = ("Janeiro", "Fevereiro", "Março")
print(f"mes: {meses[0]}")
# Out:
# mes: Janeiro

# %% [markdown]
# #### Exercício 24
#
# Crie um dicionário chamado filme com as seguintes chaves e valores:
#
# - titulo = "O Poderoso Chefão",
# - ano = 1972
# - diretor = "Francis Ford Coppola"

# %%
# Solução

filme = {

    "titulo": "O poderoso Chefão",
    "ano": 1972,
    "diretor": "Francis Ford Coppola"
}

print(f"Informações do filme no dicionario: {filme}")
# Out:
# Informações do filme no dicionario: {'titulo': 'O poderoso Chefão', 'ano': 1972, 'diretor': 'Francis Ford Coppola'}

# %% [markdown]
# #### Exercício 25
#
# Acesse e imprima o ano de lançamento do filme a partir do dicionário.

# %%
# Solução
print(f"O filme foi lançado em: {filme["ano"]}")
# Out:
# O filme foi lançado em: 1972

# %% [markdown]
# #### Exercício 26
#
# Adicione uma nova chave genero com o valor "Drama" ao dicionário filme e imprima o dicionário completo.

# %%
# Solução

filme["genero"] = "Drama"
print(f"o dicionario foi atualizada:\n {filme}")
# Out:
# o dicionario foi atualizada:
#  {'titulo': 'O poderoso Chefão', 'ano': 1972, 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 27
#
# Modifique o valor da chave ano para 1973 e imprima o dicionário atualizado.

# %%
# Solução
filme["ano"] = 1973
print(f"o ano do filme foi alterado:\n {filme}")
# Out:
# o ano do filme foi alterado:
#  {'titulo': 'O poderoso Chefão', 'ano': 1973, 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 28
#
# Crie uma lista com os seguintes números: [1, 2, 2, 3, 4, 4, 5, 1]. Use um conjunto para remover os números duplicados e imprima o resultado.

# %%
# Solução

numeros = {1,2,2,3,4,4,5,1}
print(f"Conjunto de números (sem duplicatas): {numeros}")
# Out:
# Conjunto de números (sem duplicatas): {1, 2, 3, 4, 5}

# %% [markdown]
# #### Exercício 29
#
# Crie dois conjuntos:
#
# - set_a = {1, 2, 3, 4}
# - set_b = {3, 4, 5, 6}
#
# Encontre e imprima a interseção entre os dois conjuntos (os elementos que estão em ambos).

# %%
# Solução
set_a = {1,2,3,4}
set_b = {3,4,5,6}

# %% [markdown]
# #### Exercício 30
#
# Escreva um programa que peça ao usuário para digitar sua altura em metros (ex: 1.75) e seu peso em quilogramas (ex: 68.5). Calcule o Índice de Massa Corporal (IMC) usando a fórmula IMC = peso / (altura * altura) e imprima o resultado formatado com duas casas decimais.

# %%
# Solução
altura = float(input("Digite sua altura (em metros): "))
peso = float(input("Digite seu peso (em quilogramas): "))

imc = peso / (altura * altura)

print(f"Seu IMC é: {imc:.2f}")
# Out:
# Digite sua altura (em metros):  1.65
# Digite seu peso (em quilogramas):  60
# Seu IMC é: 22.04

# %% [markdown]
# # Fim
